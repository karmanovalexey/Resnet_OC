# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from PIL import Image
from utils.kitti import Kitti360

# %%
kit = Kitti360('/workspace/KITTI-360')

# %%
i, l = next(iter(kit))

# %%
i
# Out:
# array([[[-1.9980307 , -1.9637812 , -1.9124069 , ...,  1.2385478 ,
#          -2.117904  , -2.117904  ],
#         [-1.980906  , -1.980906  , -1.9466565 , ...,  1.1186745 ,
#          -2.117904  , -2.117904  ],
#         [-1.9295317 , -1.9466565 , -1.9466565 , ...,  1.1700488 ,
#          -2.117904  , -2.117904  ],
#         ...,
#         [-1.8610327 , -1.8610327 , -1.843908  , ..., -0.57667613,
#          -2.117904  , -2.117904  ],
#         [-1.8610327 , -1.843908  , -1.843908  , ..., -0.55955136,
#          -2.117904  , -2.117904  ],
#         [-1.8952821 , -1.8952821 , -1.8952821 , ..., -0.45680285,
#          -2.117904  , -2.117904  ]],
#
#        [[-1.7556022 , -1.7556022 , -1.7731092 , ...,  2.4285715 ,
#          -2.0357141 , -2.0357141 ],
#         [-1.8081232 , -1.8081232 , -1.7906162 , ...,  2.4285715 ,
#          -2.0357141 , -2.0357141 ],
#         [-1.8081232 , -1.8256302 , -1.8256302 , ...,  2.4285715 ,
#          -2.0357141 , -2.0357141 ],
#         ...,
# ...

# %%
l
# Out:
# array([[[21, 21, 21, ..., 23,  0,  0],
#         [21, 21, 21, ..., 23,  0,  0],
#         [21, 21, 21, ..., 23,  0,  0],
#         ...,
#         [ 9,  9,  9, ...,  7,  0,  0],
#         [ 9,  9,  9, ...,  7,  0,  0],
#         [ 9,  9,  9, ...,  7,  0,  0]]])

# %%
plt.imshow(np.moveaxis(i,0,2))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(np.moveaxis(l,0,2))
